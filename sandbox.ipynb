# %% [markdown]
# # Basic setup

# %%
# ruff: noqa
import asyncio
from calendar import c
import json
import os
from re import A
import sys
import time


# Add the src directory to Python path so we can import codegen
sys.path.insert(0, os.path.join(os.getcwd(), "src"))

from dbt_mcp.lsp.lsp_client import LSPClient
from dbt_mcp.lsp.lsp_binary_manager import detect_lsp_binary
from dbt_mcp.lsp.lsp_connection import LSPConnection
import logging

# setup logger
logging.basicConfig(level=logging.INFO)

lsp_binary_info = detect_lsp_binary()

if not lsp_binary_info:
    raise ValueError("No LSP binary found")

print(lsp_binary_info)

project_dir = "/Users/rene.ruck/DevPlayground/copilot-jaffle-shop-testing"
lsp_connection = LSPConnection(
    binary_path=lsp_binary_info.path,
    cwd=project_dir,
)
await lsp_connection.start()
await lsp_connection.initialize()
print("===============")
lsp_client = LSPClient(lsp_connection)
# measure compile time
# start_time = time.time()
# await lsp_client.compile()
# print(f"compile complete in {time.time() - start_time} seconds")

nodes = await lsp_client._list_nodes("customers")
print(f"list nodes returned {len(nodes)} nodes")

print("getting column lineage")
column_lineage = await lsp_client.get_column_lineage(
    "model.jaffle_shop.customers", "customer_id"
)
print(f"column lineage retruned {len(column_lineage)} nodes")
await asyncio.sleep(5)
print("getting model lineage")
model_lineage = await lsp_client.get_model_lineage("+model.jaffle_shop.customers+")
print(f"model lineage retruned {len(model_lineage)} nodes")
# Out:
# INFO:dbt_mcp.lsp.lsp_connection:Configured event loop with exception handler
# INFO:dbt_mcp.lsp.lsp_connection:LSP server started with PID: 97560
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'id': 20, 'method': 'initialize', 'params': {'processId': None, 'rootUri': None, 'clientInfo': {'name': 'dbt-mcp', 'version': '1.0.0'}, 'capabilities': {'workspace': {'applyEdit': True, 'executeCommand': {'dynamicRegistration': True}, 'workspaceFolders': True, 'configuration': True, 'fileOperations': {'dynamicRegistration': True}, 'diagnostics': {'refreshSupport': True}}, 'notebookDocument': {'synchronization': {'dynamicRegistration': True, 'executionSummarySupport': True}}}, 'initializationOptions': {'project-dir': 'file:///', 'command-prefix': '60e9aade-6dfb-44b5-844e-84cbff928a7f'}}}
# INFO:dbt_mcp.lsp.lsp_connection:Received response for request {'jsonrpc': '2.0', 'id': 20, 'result': {'capabilities': {'codeLensProvider': {'resolveProvider': False}, 'completionProvider': {'completionItem': {'labelDetailsSupport': True}, 'resolveProvider': False, 'triggerCharacters': ['{', "'", '.']}, 'definitionProvider': True, 'executeCommandProvider': {'commands': ['dbt.listNodes', 'dbt.getCurrentNode', 'dbt.compileLsp', 'dbt.cancelCompilation', 'dbt.refreshSources', 'dbt.clearTarget']}, 'hoverProvider': True, 'inlayHintProvider': True, 'referencesProvider': True, 'renameProvider': True, 'signatureHelpProvider': {'retriggerCharacters': [','], 'triggerCharacters': ['(']}, 'textDocumentSync': {'change': 2, 'openClose': True, 'save': {}}, 'workspace': {'fileOperations': {'willRename': {'filters': [{'pattern': {'glob': '**/*.{sql,csv}', 'matches': 'file'}, 'scheme': 'file'}]}}}}, 'serverInfo': {'name': 'dbt-lsp', 'version': '2.0.0-preview.29'}}}
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'method': 'initialized', 'params': {}}
# INFO:dbt_mcp.lsp.lsp_connection:LSP server initialized successfully
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'id': 21, 'method': 'workspace/executeCommand', 'params': {'command': 'dbt.compileLsp', 'arguments': []}}
# INFO:dbt_mcp.lsp.lsp_connection:Received response for request {'jsonrpc': '2.0', 'id': 21}
# INFO:dbt_mcp.lsp.lsp_connection:LSP request {'jsonrpc': '2.0', 'id': 0, 'method': 'workspace/configuration', 'params': {'items': [{'section': 'dbt'}]}}
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'id': 0, 'result': None}
# INFO:dbt_mcp.lsp.lsp_connection:LSP request {'jsonrpc': '2.0', 'id': 1, 'method': 'window/workDoneProgress/create', 'params': {'token': 'e6e216de-db4d-46c5-a607-59c554b29ffe'}}
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'id': 1, 'result': None}
# LspBinaryInfo(path='/Users/rene.ruck/Library/Application Support/cursor/User/globalStorage/dbtlabsinc.dbt/bin/dbt-lsp', version='2.0.0-preview.29')
# ===============
# INFO:dbt_mcp.lsp.lsp_connection:LSP request {'jsonrpc': '2.0', 'id': 2, 'method': 'workspace/codeLens/refresh'}
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'id': 2, 'result': None}
# INFO:dbt_mcp.lsp.lsp_connection:Received event LspEventName.compileComplete - {'jsonrpc': '2.0', 'method': 'dbt/lspCompileComplete', 'params': {'adapter_type': 'snowflake', 'adapter_unique_id': 'b2683786a2936eb84340c27d9733eec3', 'cause': 'compileLspCommand', 'compile_type': 'full', 'dbt_version': '2.0.0-preview.29', 'duration_ms': 1908, 'errors': [{'code': '1000', 'message': "dbt1000: Detected unsafe introspection which may lead to non-deterministic static analysis. To suppress this warning, set static_analysis to 'unsafe' in the nodes' configuration. Learn more: https://docs.getdbt.com/docs/fusion/new-concepts. Nodes: 'model.jaffle_shop.metricflow_time_spine' (execute)", 'severity': 'Warning'}, {'code': '1005', 'message': "dbt1005: Ref 'customerers' not found in project. Searched for 'jaffle_shop.customerers, customerers'\n  --> models/copilot-test.sql:5:6", 'severity': 'Error'}, {'code': '1501', 'message': 'dbt1501: Failed to render SQL not a key type: ref not found for package: jaffle_shop, model: customerers, version: None\n(in models/copilot-test.sql:5:6)\n  --> models/copilot-test.sql:5:6', 'severity': 'Error'}], 'models_count': 14, 'project_id': '06e5b98c2db46f8a72cc4f66410e9b3b'}}
# INFO:dbt_mcp.lsp.lsp_connection:Recorded compile complete event
# INFO:dbt_mcp.lsp.lsp_client:Listing nodes
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'id': 22, 'method': 'workspace/executeCommand', 'params': {'command': 'dbt.listNodes', 'arguments': ['customers']}}
# INFO:dbt_mcp.lsp.lsp_connection:Received response for request {'jsonrpc': '2.0', 'id': 22, 'result': {'error': None, 'grain': 'project', 'nodes': [{'access': 'protected', 'alias': 'customers', 'checksum': {'checksum': '664488ec4c2dc2e6b48f35ec05d81258c5c7716af3f044435815046378f1d224', 'name': 'SHA256'}, 'columns': {'COUNT_LIFETIME_ORDERS': {'config': {}, 'constraints': [], 'data_type': 'NUMBER(18,0)', 'description': '', 'meta': {}, 'name': 'COUNT_LIFETIME_ORDERS', 'tags': []}, 'CUSTOMER_ID': {'config': {}, 'constraints': [], 'data_type': 'VARCHAR', 'description': '', 'meta': {}, 'name': 'CUSTOMER_ID', 'tags': []}, 'CUSTOMER_NAME': {'config': {}, 'constraints': [], 'data_type': 'VARCHAR', 'description': '', 'meta': {}, 'name': 'CUSTOMER_NAME', 'tags': []}, 'CUSTOMER_TYPE': {'config': {}, 'constraints': [], 'data_type': 'VARCHAR not null', 'description': '', 'meta': {}, 'name': 'CUSTOMER_TYPE', 'tags': []}, 'FIRST_ORDERED_AT': {'config': {}, 'constraints': [], 'data_type': 'TIMESTAMP_NTZ(9)', 'description': '', 'meta': {}, 'name': 'FIRST_ORDERED_AT', 'tags': []}, 'LAST_ORDERED_AT': {'config': {}, 'constraints': [], 'data_type': 'TIMESTAMP_NTZ(9)', 'description': '', 'meta': {}, 'name': 'LAST_ORDERED_AT', 'tags': []}, 'LIFETIME_SPEND': {'config': {}, 'constraints': [], 'data_type': 'NUMBER(28,2)', 'description': '', 'meta': {}, 'name': 'LIFETIME_SPEND', 'tags': []}, 'LIFETIME_SPEND_PRETAX': {'config': {}, 'constraints': [], 'data_type': 'NUMBER(28,2)', 'description': '', 'meta': {}, 'name': 'LIFETIME_SPEND_PRETAX', 'tags': []}, 'LIFETIME_TAX_PAID': {'config': {}, 'constraints': [], 'data_type': 'NUMBER(28,2)', 'description': '', 'meta': {}, 'name': 'LIFETIME_TAX_PAID', 'tags': []}}, 'config': {'access': None, 'alias': None, 'batch_size': None, 'begin': None, 'catalog_name': None, 'column_types': None, 'concurrent_batches': None, 'contract': None, 'database': None, 'description': None, 'docs': None, 'enabled': True, 'event_time': None, 'freshness': None, 'full_refresh': None, 'grants': None, 'group': None, 'incremental_predicates': None, 'incremental_strategy': None, 'location': None, 'lookback': None, 'materialized': 'table', 'merge_exclude_columns': None, 'merge_update_columns': None, 'meta': None, 'on_configuration_change': None, 'on_schema_change': None, 'packages': None, 'persist_docs': None, 'post_hook': None, 'pre_hook': None, 'predicates': None, 'quoting': {'database': False, 'identifier': False, 'schema': False, 'snowflake_ignore_case': False}, 'schema': None, 'sql_header': None, 'static_analysis': None, 'table_format': None, 'tags': None, 'unique_key': None}, 'constraints': [], 'contract': None, 'database': 'development', 'depends_on': {'macros': [], 'nodes': ['model.jaffle_shop.stg_customers', 'model.jaffle_shop.orders'], 'nodes_with_ref_location': [['model.jaffle_shop.stg_customers', {'col': 19, 'expanded': None, 'file': 'models/marts/customers.sql', 'index': 40, 'line': 5}], ['model.jaffle_shop.orders', {'col': 19, 'expanded': None, 'file': 'models/marts/customers.sql', 'index': 103, 'line': 11}]]}, 'deprecation_date': None, 'description': 'Customer overview data mart, offering key details for each unique customer. One row per customer.', 'enabled': True, 'event_time': None, 'fqn': ['jaffle_shop', 'marts', 'customers'], 'freshness': None, 'group': None, 'incremental_strategy': None, 'language': 'sql', 'latest_version': None, 'materialized': 'table', 'meta': {}, 'metrics': [], 'name': 'customers', 'name_span': {'start': {'col': 0, 'expanded': None, 'file': '', 'index': 0, 'line': 0}, 'stop': {'col': 0, 'expanded': None, 'file': '', 'index': 0, 'line': 0}}, 'original_file_path': 'models/marts/customers.sql', 'package_name': 'jaffle_shop', 'patch_path': 'models/marts/customers.yml', 'path': 'models/marts/customers.sql', 'primary_key': [], 'quoting': {'database': False, 'identifier': False, 'schema': False}, 'quoting_ignore_case': False, 'raw_code': '--placeholder--', 'refs': [{'name': 'stg_customers', 'package': None, 'v ...
# INFO:dbt_mcp.lsp.lsp_client:Requesting column lineage for model.jaffle_shop.customers.customer_id
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'id': 23, 'method': 'workspace/executeCommand', 'params': {'command': 'dbt.listNodes', 'arguments': ['+column:model.jaffle_shop.customers.CUSTOMER_ID+']}}
# INFO:dbt_mcp.lsp.lsp_connection:Received response for request {'jsonrpc': '2.0', 'id': 23, 'result': {'error': None, 'grain': 'column', 'nodes': [{'is_primary_key': False, 'materialized': 'table', 'name': 'CUSTOMER_ID', 'node_name': 'customers', 'op': 'copy', 'original_file_path': 'models/marts/customers.sql', 'parents': ['model.jaffle_shop.stg_customers.CUSTOMER_ID'], 'resource_type': 'model', 'transformation_type': 'passthrough', 'unique_id': 'model.jaffle_shop.customers.CUSTOMER_ID'}, {'is_primary_key': False, 'materialized': 'view', 'name': 'CUSTOMER_ID', 'node_name': 'stg_customers', 'op': 'copy', 'original_file_path': 'models/staging/stg_customers.sql', 'parents': ['source.jaffle_shop.ecom.raw_customers.ID'], 'resource_type': 'model', 'transformation_type': 'rename', 'unique_id': 'model.jaffle_shop.stg_customers.CUSTOMER_ID'}, {'is_primary_key': False, 'materialized': 'external', 'name': 'ID', 'node_name': 'raw_customers', 'op': 'unknown', 'original_file_path': 'models/staging/__sources.yml', 'parents': [], 'resource_type': 'source', 'transformation_type': 'raw', 'unique_id': 'source.jaffle_shop.ecom.raw_customers.ID'}]}}
# list nodes returned 1 nodes
# getting column lineage
# column lineage retruned 1 nodes
# INFO:dbt_mcp.lsp.lsp_client:Listing nodes
# INFO:dbt_mcp.lsp.lsp_connection:Sending message: {'jsonrpc': '2.0', 'id': 24, 'method': 'workspace/executeCommand', 'params': {'command': 'dbt.listNodes', 'arguments': ['+model.jaffle_shop.customers+']}}
# INFO:dbt_mcp.lsp.lsp_connection:Received response for request {'jsonrpc': '2.0', 'id': 24, 'result': {'error': None, 'grain': 'project', 'nodes': [{'access': 'protected', 'alias': 'customers', 'checksum': {'checksum': '664488ec4c2dc2e6b48f35ec05d81258c5c7716af3f044435815046378f1d224', 'name': 'SHA256'}, 'columns': {'COUNT_LIFETIME_ORDERS': {'config': {}, 'constraints': [], 'data_type': 'NUMBER(18,0)', 'description': '', 'meta': {}, 'name': 'COUNT_LIFETIME_ORDERS', 'tags': []}, 'CUSTOMER_ID': {'config': {}, 'constraints': [], 'data_type': 'VARCHAR', 'description': '', 'meta': {}, 'name': 'CUSTOMER_ID', 'tags': []}, 'CUSTOMER_NAME': {'config': {}, 'constraints': [], 'data_type': 'VARCHAR', 'description': '', 'meta': {}, 'name': 'CUSTOMER_NAME', 'tags': []}, 'CUSTOMER_TYPE': {'config': {}, 'constraints': [], 'data_type': 'VARCHAR not null', 'description': '', 'meta': {}, 'name': 'CUSTOMER_TYPE', 'tags': []}, 'FIRST_ORDERED_AT': {'config': {}, 'constraints': [], 'data_type': 'TIMESTAMP_NTZ(9)', 'description': '', 'meta': {}, 'name': 'FIRST_ORDERED_AT', 'tags': []}, 'LAST_ORDERED_AT': {'config': {}, 'constraints': [], 'data_type': 'TIMESTAMP_NTZ(9)', 'description': '', 'meta': {}, 'name': 'LAST_ORDERED_AT', 'tags': []}, 'LIFETIME_SPEND': {'config': {}, 'constraints': [], 'data_type': 'NUMBER(28,2)', 'description': '', 'meta': {}, 'name': 'LIFETIME_SPEND', 'tags': []}, 'LIFETIME_SPEND_PRETAX': {'config': {}, 'constraints': [], 'data_type': 'NUMBER(28,2)', 'description': '', 'meta': {}, 'name': 'LIFETIME_SPEND_PRETAX', 'tags': []}, 'LIFETIME_TAX_PAID': {'config': {}, 'constraints': [], 'data_type': 'NUMBER(28,2)', 'description': '', 'meta': {}, 'name': 'LIFETIME_TAX_PAID', 'tags': []}}, 'config': {'access': None, 'alias': None, 'batch_size': None, 'begin': None, 'catalog_name': None, 'column_types': None, 'concurrent_batches': None, 'contract': None, 'database': None, 'description': None, 'docs': None, 'enabled': True, 'event_time': None, 'freshness': None, 'full_refresh': None, 'grants': None, 'group': None, 'incremental_predicates': None, 'incremental_strategy': None, 'location': None, 'lookback': None, 'materialized': 'table', 'merge_exclude_columns': None, 'merge_update_columns': None, 'meta': None, 'on_configuration_change': None, 'on_schema_change': None, 'packages': None, 'persist_docs': None, 'post_hook': None, 'pre_hook': None, 'predicates': None, 'quoting': {'database': False, 'identifier': False, 'schema': False, 'snowflake_ignore_case': False}, 'schema': None, 'sql_header': None, 'static_analysis': None, 'table_format': None, 'tags': None, 'unique_key': None}, 'constraints': [], 'contract': None, 'database': 'development', 'depends_on': {'macros': [], 'nodes': ['model.jaffle_shop.stg_customers', 'model.jaffle_shop.orders'], 'nodes_with_ref_location': [['model.jaffle_shop.stg_customers', {'col': 19, 'expanded': None, 'file': 'models/marts/customers.sql', 'index': 40, 'line': 5}], ['model.jaffle_shop.orders', {'col': 19, 'expanded': None, 'file': 'models/marts/customers.sql', 'index': 103, 'line': 11}]]}, 'deprecation_date': None, 'description': 'Customer overview data mart, offering key details for each unique customer. One row per customer.', 'enabled': True, 'event_time': None, 'fqn': ['jaffle_shop', 'marts', 'customers'], 'freshness': None, 'group': None, 'incremental_strategy': None, 'language': 'sql', 'latest_version': None, 'materialized': 'table', 'meta': {}, 'metrics': [], 'name': 'customers', 'name_span': {'start': {'col': 0, 'expanded': None, 'file': '', 'index': 0, 'line': 0}, 'stop': {'col': 0, 'expanded': None, 'file': '', 'index': 0, 'line': 0}}, 'original_file_path': 'models/marts/customers.sql', 'package_name': 'jaffle_shop', 'patch_path': 'models/marts/customers.yml', 'path': 'models/marts/customers.sql', 'primary_key': [], 'quoting': {'database': False, 'identifier': False, 'schema': False}, 'quoting_ignore_case': False, 'raw_code': '--placeholder--', 'refs': [{'name': 'stg_customers', 'package': None, 'v ...
# getting model lineage
# model lineage retruned 1 nodes
